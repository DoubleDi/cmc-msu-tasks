# %% [markdown]
# # Дорожкин Денис 425 группа
# # Отчет

# %%
import numpy as np

# %% [markdown]
# ## 1. нерелигиозный художник предпочитать написать солнце вместо бог

# %% [markdown]
# ### tf:

# %% [markdown]
# бог отец бог сын и бог дух святой
# <br>оценка 0
# <br>строение солнце
# <br>оценка 0
# <br>фотосфера образовывать видимый поверхность солнце по который определяться размер солнце расстояние от солнце и т д
# <br>оценка 1
# <br>благодаря спектроскопия быть обнаруживать новый элемент в состав солнце который называть гелий в честь древнегреческий бог солнце гелиос
# <br>оценка 0
# <br>данный работа вероятно быть написать под впечатление от наблюдение уоттса  за звезда солнце через телескоп джеймс саута и отражать увлечение художник астрономия
# <br>оценка 2
# <br>далее оценки 0
#
# Система 0,0,1,0,2,0...
# <br>Ранжировка 2,1,0...

# %%
DCG = 1 / np.log2(4) + 2 / np.log2(6)
iDCG = 2 + 1 / np.log2(3)
nDCG_tf_1 = DCG / iDCG

print "nDCG: ", nDCG_tf_1
# Out:
# nDCG:  0.484127564691

# %% [markdown]
# ### tf-idf:

# %% [markdown]
# техника уоттса  резко отличаться от техника большинство художник тот время предпочитать заглаживать живописный поверхность
# <br>оценка 1
# <br>данный работа вероятно быть написать под впечатление от наблюдение уоттса  за звезда солнце через телескоп джеймс саута и отражать увлечение художник астрономия
# <br>оценка 2
# <br>картина солнце написать масло на холст а ее размер составлять см
# <br>оценка 0
# <br>в приводить ниже таблица по убывание показывать доля нерелигиозный часть население страна
# <br>оценка 0
# <br>картина написать в форма стилизованный морской пейзаж преимущественно яркий цветок
# <br>далее оценки 0
#
# Система 1,2,0,0,0,0...
# <br>Ранжировка 2,1,0...

# %%
DCG = 1 + 2 / np.log2(3)
iDCG = 2 + 1 / np.log2(3)
nDCG_idf_1 = DCG / iDCG

print "nDCG: ", nDCG_idf_1
# Out:
# nDCG:  0.859718699852

# %% [markdown]
# ### два композитор основоположник азербайджанский симфонический музыка не только дружить но и родиться в один день

# %% [markdown]
# ### tf:

# %% [markdown]
# не обходить композитор сторона и опыт европейский и в первый очередь русский композитор сплетать он с народный музыка и выводить такой образ последний на мировой уровень
# <br>оценка 1
# <br>в предисловие к основа азербайджанский народный музыка композитор писать
# <br>оценка 0
# <br>абдул муслим магомет оглы магомаев сентябрь грозный терский область российский империя июль нальчик ссср азербайджанский советский композитор и дирижер заслуживать деятель искусство азербайджанский сср один из основоположник азербайджанский классический музыка его имя называть азербайджанский государственный филармония
# <br>оценка 1
# <br>виноградов в свой книга узеир гаджибеков и азербайджанский музыка писать
# <br>оценка 0
# <br>но в тот же время он продолжать считать что азербайджанский музыка не должный оставаться всегда монодичной
# <br>оценка 0
# <br>далее оценки 0
#
# Система 1,0,1,0,0...
# <br>Ранжировка 1,1,0...

# %%
DCG = 1 + 1 / np.log2(4)
iDCG = 1 + 1 / np.log2(3)
nDCG_tf_2 = DCG / iDCG

print "nDCG: ", nDCG_tf_2
# Out:
# nDCG:  0.919720789148

# %% [markdown]
# ### tf-idf:

# %% [markdown]
# однако узеир гаджибеков известный на родина не только как композитор и меценат
# <br>оценка 1
# <br>с другой же сторона далеко не всякий музыка написать или перелагать для исполнение симфонический оркестр являться по свой внутренний свойство и качество музыка заведомо симфонический
# <br>оценка 1
# <br>хотя в большинство случай симфонический музыка предназначать для исполнение симфонический оркестр но то не менее симфонический по свой идейно содержательный значимость структура формообразование и специфика композиционный развитие мочь быть также и музыкальный произведение написать для какой-либо иной состав исполнитель как и для отдельный солировать инструмент или хор акапелла
# <br>оценка 1
# <br>за два день до представление быть убивать задействовать в постановка в качество режиссер гусейн араблинский  но премьера состояться и быть удачный
# <br>оценка 0
# <br>при это рисовать не только декоративный мотив но и исторический портрет сцена охота и сражение
# <br>оценка 0
# <br>далее оценки 0
#
# Система 1,1,1,0...
# <br>Ранжировка 1,1,1,0...

# %%
DCG = 1 + 1 / np.log2(3) + 1 / np.log2(4)
iDCG = 1 + 1 / np.log2(3) + 1 / np.log2(4)
nDCG_idf_2 = DCG / iDCG

print "nDCG: ", nDCG_idf_2
# Out:
# nDCG:  1.0

# %% [markdown]
# ### ерундопель хороший под водка

# %% [markdown]
# ### tf:

# %% [markdown]
# ерундопель подавать надо c водка
# <br>оценка 2
# <br>водка становиться подразделяться на водка и водка особый
# <br>оценка 0
# <br>предлагаться признавать исключительный право польша продавать и рекламировать на внешний рынок под имя водка свой товар а именно водка выборову
# <br>оценка 0
# <br>только водка из россия быть настоящий русский водка
# <br>оценка 0
# <br>основываться на этот данные менделеев разрабатывать рецептура водка под название московский особенный который в год быть запатентовывать российский правительство как русский национальный водка
# <br>оценка 0
# <br>далее оценки 0
#
# Система 2,0...
# <br>Ранжировка 2,0...

# %%
DCG = 2
iDCG = 2
nDCG_tf_3 = DCG / iDCG + 0.0

print "nDCG: ", nDCG_tf_3
# Out:
# nDCG:  1.0

# %% [markdown]
# ### tf-idf:

# %% [markdown]
# ерундопель подавать надо с водка
# <br>оценка 2
# <br>ерундопель спрашивать удивленно это пирожок
# <br>оценка 0
# <br>ерундопель закусочный салат из икра рыба и овощ
# <br>оценка 1
# <br>сборник рассказ татьяна михайловская называться ерундопель и другой
# <br>оценка 0
# <br>основываться на этот данные менделеев разрабатывать рецептура водка под название московский особенный который в год быть запатентовывать российский правительство как русский национальный водка
# <br>оценка 0
# <br>далее оценки 0
#
# Система 2,0,1,0,0...
# <br>Ранжировка 2,1,0...

# %%
DCG = 2 + 1 / np.log2(4)
iDCG = 2 + 1 / np.log2(3)
nDCG_idf_3 = DCG / iDCG

print "nDCG: ", nDCG_idf_3
# Out:
# nDCG:  0.95023441679

# %% [markdown]
# ### Среднее

# %%
print "tf:", (nDCG_tf_1 + nDCG_tf_2 + nDCG_tf_3) / 3
print "tf-idf:", (nDCG_idf_1 + nDCG_idf_2 + nDCG_idf_3) / 3
# Out:
# tf: 0.801282784613
# tf-idf: 0.936651038881
